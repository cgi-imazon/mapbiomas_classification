# %%
import pandas as pd

pd.options.display.float_format = "{:,.2f}".format

# %%
df = pd.read_excel('data/exemplo_outliers.xlsx')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '...1', 'ano', 'UF', 'municipio', 'dados.fornecedor',
#        'dados.CNPJ.CPF', 'dados.tipo', 'dados.n_doc', 'dados.emissao',
#        'valor_total_nota_fiscal', 'item', 'un', 'qt', 'valor_un', 'valor',
#        'codigo', 'corte', 'deflator_acum', 'valor_real', 'cluster',
#        'valor_real_USD', 'produtos', 'un_adj', 'has_change', 'unit_kg',
#        'price_kg', 'median_price', 'rule_apply', 'outlier', 'rule_version',
#        'rule_id', 'valor_un_ref', '__index_level_0__', 'qt_kg'],
#       dtype='object')

# %%
fields = ['item', 'un', 'qt', 'unit_kg','valor_un', 'valor', 'price_kg', 'median_price', 'valor_un_ref', 'qt_kg']

df[fields]
# Out:
#                                                item     un  \
# 0           CARNE BOVINA DE 2ª, RESFRIADA/CONGELADA     KG
# 1           CARNE BOVINA DE 1ª, RESFRIADA/CONGELADA     KG
# 2           CARNE BOVINA DE 1ª, RESFRIADA/CONGELADA     KG
# 3                                    OVO DE GALINHA     UN
# 4                                    OVO DE GALINHA     UN
# 5           CARNE BOVINA DE 2ª, RESFRIADA/CONGELADA     KG
# 6       CARNE BOVINA, PRE-PREAPADA, DIVERSOS CORTES     KG
# 7           CARNE BOVINA DE 2ª, RESFRIADA/CONGELADA     KG
# 8           CARNE BOVINA DE 2ª, RESFRIADA/CONGELADA     KG
# 9           CARNE BOVINA DE 2ª, RESFRIADA/CONGELADA     KG
# 10                                   OVO DE GALINHA     DZ
# 11                                   OVO DE GALINHA     UN
# 12                                         SALSICHA  GRAMA
# 13  ARROZ COM CHARQUE E MANDIOQUINHA, MISTURA EM PO     KG
# 14                                   OVO DE GALINHA     DZ
# ...
